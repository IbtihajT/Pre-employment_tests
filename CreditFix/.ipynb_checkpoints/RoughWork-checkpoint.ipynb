# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataDictPath = "./data/Data Dictionary.xlsx"
dataDict = pd.read_excel(dataDictPath)

# %%
dataDict
# Out:
#                           Variable Name  \
# 0                              UniqueID
# 1                          loan_default
# 2                      disbursed_amount
# 3                            asset_cost
# 4                                   ltv
# 5                             branch_id
# 6                           supplier_id
# 7                       manufacturer_id
# 8                       Current_pincode
# 9                         Date.of.Birth
# 10                      Employment.Type
# 11                        DisbursalDate
# 12                             State_ID
# 13                     Employee_code_ID
# 14                    MobileNo_Avl_Flag
# 15                          Aadhar_flag
# 16                             PAN_flag
# 17                         VoterID_flag
# 18                         Driving_flag
# 19                        Passport_flag
# 20                    PERFORM_CNS.SCORE
# 21        PERFORM_CNS.SCORE.DESCRIPTION
# ...
